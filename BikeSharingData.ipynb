# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns

import warnings
warnings.simplefilter('ignore')
# %matplotlib inline

# %%
df= pd.read_csv('train_bikes.csv')

# %%
df.sample(10)
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 10407  2012-11-19 01:00:00       4        0           1        2  14.76
# 2363   2011-06-06 09:00:00       2        0           1        1  28.70
# 9896   2012-10-16 17:00:00       4        0           1        1  21.32
# 9725   2012-10-09 14:00:00       4        0           1        2  22.14
# 2280   2011-06-02 22:00:00       2        0           1        1  26.24
# 10488  2012-12-03 10:00:00       4        0           1        1  18.04
# 9945   2012-10-18 18:00:00       4        0           1        2  22.96
# 129    2011-01-06 15:00:00       1        0           1        1  11.48
# 670    2011-02-11 06:00:00       1        0           1        1   4.10
# 8173   2012-07-01 22:00:00       3        0           0        1  33.62
#
#         atemp  humidity  windspeed  casual  registered  count
# 10407  17.425        66    15.0013       0          19     19
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %% [markdown]
# ### Observations
# In this dataset we have:
# 8 int dtypes, 3 float64 dtypes and 1 object dtype
# - datetime: its in the format of YYYY-MM-DD with time hh:mm:ss
# - season: In which season
# - holiday: No. of holidays
# - workingday: No. of working days
# - weather: In which weather we had bike sharing
# - temp: temperature of weather
# - humidity: humudity of the weather
# - windspeed: speed of the wind
# - casual: casual customers
# - registered: No. of registered customers
# - count: total no. of registered and casual customers

# %%
#counting values of season column
df.season.value_counts()
# Out:
# 4    2734
# 2    2733
# 3    2733
# 1    2686
# Name: season, dtype: int64

# %%
plt.style.use('ggplot')

# %%
#plotting the counts based on season
plt.figure(figsize = (15, 6 ))
plt.scatter(x = df['season'], y= df['count'])
plt.xlabel('Season', fontsize= 20)
plt.ylabel('Count', fontsize= 20)
plt.show()

# %% [markdown]
# #### Observation:
# - as we can notice most of the count of customers are in the 3rd season with above 90% of the count comapred to other saesons
# - the next season is in the 4th season almost same as the 3rd season and next is the 2nd season

# %%
# counting values of holiday column
df.holiday.value_counts()
# Out:
# 0    10575
# 1      311
# Name: holiday, dtype: int64

# %%
#plotting the counts based on holiday
plt.figure(figsize = (15, 6 ))
plt.scatter(x = df['holiday'], y= df['count'])
plt.xlabel('Holiday', fontsize= 20)
plt.ylabel('Count', fontsize= 20)
plt.show()

# %%
# counting values of workingday column
df.workingday.value_counts()
# Out:
# 1    7412
# 0    3474
# Name: workingday, dtype: int64

# %%
# Plotting the counts based on working day
plt.figure(figsize = (15, 6))
plt.scatter(x = df['workingday'], y = df['count'])
plt.xlabel('Working Day', fontsize = 24)
plt.ylabel('Count', fontsize = 20)
plt.show()

# %%
df.temp.value_counts()
# Out:
# 14.76    467
# 26.24    453
# 28.70    427
# 13.94    413
# 18.86    406
# 22.14    403
# 25.42    403
# 16.40    400
# 22.96    395
# 27.06    394
# 24.60    390
# 12.30    385
# 21.32    362
# 17.22    356
# 13.12    356
# 29.52    353
# 10.66    332
# 18.04    328
# 20.50    327
# 30.34    299
# 9.84     294
# 15.58    255
# 9.02     248
# 31.16    242
# 8.20     229
# 27.88    224
# 23.78    203
# 32.80    202
# 11.48    181
# 19.68    170
# 6.56     146
# 33.62    130
# 5.74     107
# 7.38     106
# 31.98     98
# 34.44     80
# 35.26     76
# 4.92      60
# 36.90     46
# 4.10      44
# 37.72     34
# 36.08     23
# 3.28      11
# 0.82       7
# 38.54      7
# 39.36      6
# 2.46       5
# 1.64       2
# 41.00      1
# Name: temp, dtype: int64

# %%
# Plotting the counts based on temperature
plt.figure(figsize = (15, 6))
plt.scatter(x = df['temp'], y = df['count'])
plt.xlabel('Temperature', fontsize = 24)
plt.ylabel('Count', fontsize = 20)
plt.show()

# %% [markdown]
# #### Observation:
# - the count of most bike rides in temperature are between 25 to 30 which is almost above 90% of the count
# - the next most count is temperature are between 20 to 25

# %%
df.atemp.value_counts()
# Out:
# 31.060    671
# 25.760    423
# 22.725    406
# 20.455    400
# 26.515    395
# 16.665    381
# 25.000    365
# 33.335    364
# 21.210    356
# 30.305    350
# 15.150    338
# 21.970    328
# 24.240    327
# 17.425    314
# 31.820    299
# 34.850    283
# 27.275    282
# 32.575    272
# 11.365    271
# 14.395    269
# 29.545    257
# 19.695    255
# 15.910    254
# 12.880    247
# 13.635    237
# 34.090    224
# 12.120    195
# 28.790    175
# 23.485    170
# 10.605    166
# 35.605    159
# 9.850     127
# 18.180    123
# 36.365    123
# 37.120    118
# 9.090     107
# 37.880     97
# 28.030     80
# 7.575      75
# 38.635     74
# 6.060      73
# 39.395     67
# 6.820      63
# 8.335      63
# 18.940     45
# 40.150     45
# 40.910     39
# 5.305      25
# 42.425     24
# 41.665     23
# 3.790      16
# 4.545      11
# 3.030       7
# 43.940      7
# 2.275       7
# 43.180      7
# 44.695      3
# 0.760       2
# 1.515       1
# 45.455      1
# Name: atemp, dtype: int64

# %%
# Plotting the counts based on atemp
plt.figure(figsize = (15, 6))
plt.scatter(x = df['atemp'], y = df['count'])
plt.xlabel('Temperature', fontsize = 24)
plt.ylabel('Count', fontsize = 20)
plt.show()

# %%
df.humidity.value_counts()
# Out:
# 88    368
# 94    324
# 83    316
# 87    289
# 70    259
#      ...
# 8       1
# 10      1
# 97      1
# 96      1
# 91      1
# Name: humidity, Length: 89, dtype: int64

# %%
#plotting the counts based on humidity
plt.figure(figsize =(15,6))
plt.scatter(x= df['humidity'], y=df['count'])
plt.xlabel('Humudity', fontsize= 24)
plt.ylabel('Count', fontsize= 20)
plt.show()

# %%
df.windspeed.value_counts()
# Out:
# 0.0000     1313
# 8.9981     1120
# 11.0014    1057
# 12.9980    1042
# 7.0015     1034
# 15.0013     961
# 6.0032      872
# 16.9979     824
# 19.0012     676
# 19.9995     492
# 22.0028     372
# 23.9994     274
# 26.0027     235
# 27.9993     187
# 30.0026     111
# 31.0009      89
# 32.9975      80
# 35.0008      58
# 39.0007      27
# 36.9974      22
# 43.0006      12
# 40.9973      11
# 43.9989       8
# 46.0022       3
# 56.9969       2
# 47.9988       2
# 51.9987       1
# 50.0021       1
# Name: windspeed, dtype: int64

# %%
plt.figure(figsize= (15,6))
plt.scatter(x= df['windspeed'], y= df['count'])
plt.xlabel('Windspeed', fontsize= 24)
plt.ylabel('Count', fontsize= 20)
plt.show()

# %%
df.casual.value_counts()
# Out:
# 0      986
# 1      667
# 2      487
# 3      438
# 4      354
#       ...
# 332      1
# 361      1
# 356      1
# 331      1
# 304      1
# Name: casual, Length: 309, dtype: int64

# %%
plt.figure(figsize= (15,6))
plt.scatter(x= df['casual'], y= df['count'])
plt.xlabel('Casual User', fontsize= 24)
plt.ylabel('Count', fontsize= 20)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df1= pd.read_csv('test_bikes.csv', parse_dates = ['datetime'])

# %%
df1.sample(10)
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 3869 2012-03-25 01:00:00       2        0           0        2  17.22  21.210
# 5608 2012-09-27 12:00:00       4        0           1        2  30.34  33.335
# 5859 2012-10-26 23:00:00       4        0           1        1  21.32  25.000
# 547  2011-03-23 17:00:00       2        0           1        2  16.40  20.455
# 26   2011-01-21 02:00:00       1        0           1        3   9.84  12.120
# 3717 2012-02-28 16:00:00       1        0           1        1  17.22  21.210
# 5334 2012-08-28 02:00:00       3        0           1        1  27.88  31.820
# 2266 2011-09-25 23:00:00       4        0           0        2  25.42  27.275
# 1521 2011-06-29 09:00:00       3        0           1        1  29.52  32.575
# 595  2011-03-25 17:00:00       2        0           1        2  13.12  14.395
#
#       humidity  windspeed
# 3869       100    16.9979
# 5608        48     8.9981
# 5859        83    11.0014
# ...

# %%
df1.describe()
# Out:
#             season      holiday   workingday      weather         temp  \
# count  6493.000000  6493.000000  6493.000000  6493.000000  6493.000000
# mean      2.493300     0.029108     0.685815     1.436778    20.620607
# std       1.091258     0.168123     0.464226     0.648390     8.059583
# min       1.000000     0.000000     0.000000     1.000000     0.820000
# 25%       2.000000     0.000000     0.000000     1.000000    13.940000
# 50%       3.000000     0.000000     1.000000     1.000000    21.320000
# 75%       3.000000     0.000000     1.000000     2.000000    27.060000
# max       4.000000     1.000000     1.000000     4.000000    40.180000
#
#              atemp     humidity    windspeed
# count  6493.000000  6493.000000  6493.000000
# mean     24.012865    64.125212    12.631157
# std       8.782741    19.293391     8.250151
# min       0.000000    16.000000     0.000000
# 25%      16.665000    49.000000     7.001500
# 50%      25.000000    65.000000    11.001400
# ...

# %%
print("count samples & features: ", df.shape) # printing the number of rows and columns
print("Are there missing values: ", df.isnull().values.any()) # printing if dataset has any NaN value
# Out:
# count samples & features:  (10886, 12)
# Are there missing values:  False

# %%
df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce') 
# the dtype remained as str/object, if we set param errors='coerce' 
# then if the conversion fails for any particular string then those rows are set to NaT.

# %%
#method for creating the count plot based on hour for given year
def plot_by_hour(data, year = None, agg= 'sum'):
    dd = data
    if year: dd = dd[dd.datetime.dt.year== year]
    dd.loc[:, ('hour')] = dd.datetime.dt.hour # extracting the hour data if the year in the data is equal to year passed as argument
    
    by_hour = dd.groupby(['hour', 'workingday'])['count'].agg(agg).unstack() # group by hour and working day
    return by_hour.plot(kind= 'bar', ylim=(0, 80000), figsize= (15,6), width= 0.9, title= "Year = {0}".format(year))# returning the figure group by hour

plot_by_hour(df, year= 2011) #plotting the count plot based on hour for 2011
plot_by_hour(df, year= 2012) #plotting the count plot based on hour for 2012
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.7 KB

# %%
#method for creating the count plot based on year
def plot_by_year(agg_atr, title):
    dd = df.copy()
    dd['year']= df.datetime.dt.year #extracting the year
    dd['month']= df.datetime.dt.month #extracting the month
    dd['hour']= df.datetime.dt.hour #extracting the hour
    
    by_year = dd.groupby([agg_atr, 'year'])['count'].agg('sum').unstack() # groupby year
    return by_year.plot(kind = 'bar', figsize = (15, 6), width = 0.9, title = title) # returning the figure grouped by year

plot_by_year('month', 'Rent bikes per month in 2011 and 2012') # plotting monthly bike rentals based on year
plot_by_year('hour', 'Rent bikes per hour in 2011 and 2012') # plotting hourly bike rentals based on year

plt.show()

# %%
#method to plot a graph for count per hour
def plot_hours(data, message= ''):
    dd= data.copy()
    dd['hour']= data.datetime.dt.hour #extracting the hour
    
    hours= {}
    for hour in range(24):
        hours[hour]= dd[dd.hour== hour]['count'].values
    
    plt.figure(figsize= (20, 10))
    plt.boxplot([hours[hour] for hour in range(24)])
    plt.xlabel('Hours')
    plt.ylabel('Count rent')
    plt.title('Count vs Hours' + message)
    
    axis= plt.gca()

# %%
plot_hours(df[df.datetime.dt.year == 2011], 'year 2011') # box plot for hourly count for the mentioned year
plot_hours(df[df.datetime.dt.year == 2012], 'year 2012') # box plot for hourly count for the mentioned year

# %%
df.dtypes
# Out:
# datetime      datetime64[ns]
# season                 int64
# holiday                int64
# workingday             int64
# weather                int64
# temp                 float64
# atemp                float64
# humidity               int64
# windspeed            float64
# casual                 int64
# registered             int64
# count                  int64
# dtype: object

# %%
df1.dtypes
# Out:
# datetime      datetime64[ns]
# season                 int64
# holiday                int64
# workingday             int64
# weather                int64
# temp                 float64
# atemp                float64
# humidity               int64
# windspeed            float64
# dtype: object

# %%
df.head(5)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df['hour'] = df.datetime.dt.hour # adding the hour column for train dataset

# %%
df1['hour'] = df1.datetime.dt.hour # adding the hour column for test dataset

# %%
df1.head(5)
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  hour
# 0        56    26.0027     0
# 1        56     0.0000     1
# 2        56     0.0000     2
# 3        56    11.0014     3
# 4        56    11.0014     4

# %%
plot_hours(df[df.workingday == 1], 'Working Day') # plotting hourly count of rented bikes for working days for a given year

# %%
plot_hours(df[df.workingday == 0], 'Non Working Day') # plotting hourly count of rented bikes for non-working days for a given year

# %%
# method to convert categorical data to numerical data
def categorical_to_numeric(x):
    if 0 <= x < 6:
        return 0
    elif 6 <= x < 13:
        return 1
    elif 13 <= x < 19:
        return 2
    elif 19 <= x <= 24:
        return 3

# %%
df['hour'] = df['hour'].apply(categorical_to_numeric) # applying the above conversion logic to training data
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  hour
# 0        81        0.0       3          13     16     0
# 1        80        0.0       8          32     40     0
# 2        80        0.0       5          27     32     0
# 3        75        0.0       3          10     13     0
# 4        75        0.0       0           1      1     0

# %%
df1['hour'] = df1['hour'].apply(categorical_to_numeric) # applying the above conversion logic to training data
df1.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  hour
# 0        56    26.0027     0
# 1        56     0.0000     0
# 2        56     0.0000     0
# 3        56    11.0014     0
# 4        56    11.0014     0

# %%
# drop unnecessary columns
df = df.drop(['datetime'], axis = 1)
df1 = df1.drop(['datetime'], axis = 1)

# %%
df.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    casual  registered  count  hour
# 0       3          13     16     0
# 1       8          32     40     0
# 2       5          27     32     0
# 3       3          10     13     0
# 4       0           1      1     0

# %%
df1.head()
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       1        0           1        1  10.66  11.365        56    26.0027
# 1       1        0           1        1  10.66  13.635        56     0.0000
# 2       1        0           1        1  10.66  13.635        56     0.0000
# 3       1        0           1        1  10.66  12.880        56    11.0014
# 4       1        0           1        1  10.66  12.880        56    11.0014
#
#    hour
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
#an hour by Count graph depicting average bike demand based on the hour
fig, ax= plt.subplots(figsize= (13,  6))
hours= df.groupby(['hour']).agg('mean')["count"]
hours.plot(kind= 'line', ax= ax)
plt.title('Hours vs Counts')
ax.set_xlabel('Time in Hours')
ax.set_ylabel('Average of Bike Demand')
plt.show()

# %%
# count of different temp values
a = df.groupby(['temp'])[['count']].mean()
a
# Out:
#             count
# temp
# 0.82    77.714286
# 1.64    91.500000
# 2.46    43.000000
# 3.28    19.272727
# 4.10    50.272727
# 4.92    58.416667
# 5.74    53.233645
# 6.56    68.109589
# 7.38    67.754717
# 8.20    81.995633
# 9.02    73.616935
# 9.84    86.442177
# 10.66   92.560241
# 11.48  111.066298
# 12.30  120.002597
# 13.12  148.547753
# 13.94  145.053269
# 14.76  152.957173
# 15.58  179.682353
# 16.40  170.217500
# 17.22  182.609551
# 18.04  160.878049
# 18.86  159.692118
# 19.68  185.058824
# 20.50  204.672783
# 21.32  196.480663
# 22.14  184.717122
# 22.96  212.392405
# 23.78  235.650246
# 24.60  237.182051
# 25.42  222.062035
# 26.24  232.403974
# 27.06  211.025381
# 27.88  203.433036
# 28.70  257.679157
# 29.52  277.691218
# 30.34  303.193980
# 31.16  352.801653
# 31.98  318.683673
# 32.80  355.623762
# 33.62  348.323077
# 34.44  340.225000
# 35.26  342.934211
# 36.08  362.869565
# 36.90  318.717391
# 37.72  332.176471
# 38.54  238.857143
# 39.36  317.833333
# ...

# %%
fig, ax = plt.subplots(figsize = (14, 8))
a.plot(ax = ax)
plt.show()

# %%
# count of different atemp values
a = df.groupby(['atemp'])[['count']].mean()
a
# Out:
#              count
# atemp
# 0.760     1.000000
# 1.515     3.000000
# 2.275    38.000000
# 3.030    82.285714
# 3.790    39.062500
# 4.545    66.090909
# 5.305    63.200000
# 6.060    64.876712
# 6.820    56.380952
# 7.575    55.933333
# 8.335    58.444444
# 9.090    80.000000
# 9.850    81.456693
# 10.605   95.951807
# 11.365   90.442804
# 12.120  102.656410
# 12.880   89.518219
# 13.635   94.308017
# 14.395  116.483271
# 15.150  133.967456
# 15.910  133.897638
# 16.665  148.509186
# 17.425  147.799363
# 18.180  133.585366
# 18.940  149.555556
# 19.695  179.682353
# 20.455  170.217500
# 21.210  182.609551
# 21.970  160.878049
# 22.725  159.692118
# 23.485  185.058824
# 24.240  204.672783
# 25.000  195.109589
# 25.760  179.626478
# 26.515  212.392405
# 27.275  200.503546
# 28.030  133.312500
# 28.790  142.771429
# 29.545  151.046693
# 30.305  227.291429
# 31.060  308.323398
# 31.820  258.655518
# 32.575  331.746324
# 33.335  244.107143
# 34.090  295.183036
# 34.850  277.448763
# ...

# %%
fig, ax = plt.subplots(figsize = (14, 8))
a.plot(ax = ax)
plt.show()

# %%
# count based on holiday
a = df.groupby('holiday')[['count']].mean()
a
# Out:
#               count
# holiday
# 0        191.741655
# 1        185.877814

# %%
fig, ax = plt.subplots(figsize = (14, 8))
a.plot(ax = ax)
plt.show()
